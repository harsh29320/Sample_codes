# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/270168/Downloads/personal/sprinboard/gun-violence-data_01-2013_03-2018.csv')

# %%
data.head()
# Out:
#    incident_id        date           state city_or_county  \
# 0       461105  2013-01-01    Pennsylvania     Mckeesport
# 1       460726  2013-01-01      California      Hawthorne
# 2       478855  2013-01-01            Ohio         Lorain
# 3       478925  2013-01-05        Colorado         Aurora
# 4       478959  2013-01-07  North Carolina     Greensboro
#
#                                      address  n_killed  n_injured  \
# 0  1506 Versailles Avenue and Coursin Street         0          4
# 1               13500 block of Cerise Avenue         1          3
# 2                      1776 East 28th Street         1          3
# 3           16000 block of East Ithaca Place         4          0
# 4                  307 Mourning Dove Terrace         2          2
#
#                                         incident_url  \
# 0  http://www.gunviolencearchive.org/incident/461105
# 1  http://www.gunviolencearchive.org/incident/460726
# ...

# %%
data = data.drop(columns = "incident_url")
data = data.drop(columns = "source_url")
data = data.drop(columns = "sources")
data = data.drop(columns = "incident_url_fields_missing")
data = data.drop(columns = "incident_id")
data = data.drop(columns = "gun_stolen")
data = data.drop(columns = "gun_type")
data = data.drop(columns = "incident_characteristics")
data = data.drop(columns = "latitude")
data = data.drop(columns = "longitude")
data = data.drop(columns = "location_description")
data = data.drop(columns = "n_guns_involved")
data = data.drop(columns = "notes")
data = data.drop(columns = "participant_name")
data = data.drop(columns = "address")
data = data.drop(columns = "state_house_district")
data = data.drop(columns = "state_senate_district")
data = data.drop(columns = "congressional_district")
data = data.drop(columns = "participant_relationship")
data = data.drop(columns = "participant_gender")
data = data.dropna() 
data = data[data.state != 'Delaware']
data = data[data.state != 'Maine']
data = data[data.state != 'Vermont']
data = data[data.state != 'West Virginia']
data = data[data.state != 'Wyoming']
data = data[data.state != 'Alaska']
data = data[data.state != 'North Dakota']
data = data[data.state != 'South Dakota']
data = data[data.state != 'Missouri']
data = data[data.state != 'Louisiana']
data = data[data.state != 'Georgia']
data = data[data.state != 'Mississippi']
data = data[data.state != 'Minnesota']
data = data[data.state != 'Virginia']
data = data[data.state != 'New Jersey']
data = data[data.state != 'South Carolina']
data = data[data.state != 'Alabama']
data = data[data.state != 'Connecticut']
data = data[data.state != 'Iowa']
data = data[data.state != 'Arkansas']
data = data[data.state != 'Kansas']
data = data[data.state != 'Nebraska']
data = data[data.state != 'Idaho']
data = data[data.state != 'Hawaii']
data = data[data.state != 'New Hampshire']
data = data[data.state != 'Rhode Island']
data = data[data.state != 'Montana']
data = data[data.state != 'District of Columbia']
data = data[data.n_killed != 0]
data = data[data.n_injured != 0]
data= data.sample(frac=1)
data = data[data.city_or_county != 'Akron']
data = data[data.city_or_county != 'Abilene']
data = data[data.city_or_county != 'Youngstown']
data = data[data.city_or_county != 'Ypsilanti']
data = data[data.city_or_county != 'Yonkers']
data = data[data.city_or_county != 'Albany']
data = data[data.city_or_county != 'Worcester']
data = data[data.city_or_county != 'Aberdeen']
data = data[data.city_or_county != 'Abington']
data = data[data.city_or_county != 'Addison']
data = data[data.city_or_county != 'Adelanto']
data = data[data.city_or_county != 'Ahoskie']
data = data[data.city_or_county != 'Adrian']
data = data[data.city_or_county != 'Alamogordo']
data = data[data.city_or_county != 'Allentown']
data = data[data.city_or_county != 'Aliso Viejo']
data = data[data.city_or_county != 'Winter Haven']
data = data[data.city_or_county != 'Winter Springs']
data = data[data.city_or_county != 'Alliance']
data = data[data.city_or_county != 'Alma']
data = data[data.city_or_county != 'Alpine']
data = data[data.city_or_county != 'Altadena']
data = data[data.city_or_county != 'Alsip']
data = data[data.city_or_county != 'Alturas']
data = data[data.city_or_county != 'Alvarado']
data = data[data.city_or_county != 'Amarillo']
data = data[data.city_or_county != 'American Fork']
data = data[data.city_or_county != 'Amherst']
data = data[data.city_or_county != 'Amity']
data = data[data.city_or_county != 'Anaheim']
data = data[data.city_or_county != 'Amityville']
data = data[data.city_or_county != 'Amityville (North Amityville)']
data = data[data.city_or_county != 'Anderson (Chesterfield)']
data = data[data.city_or_county != 'Annapolis']
data = data[data.city_or_county != 'Antigo']
data = data[data.city_or_county != 'Antioch']
data = data[data.city_or_county != 'Apopka']
data = data[data.city_or_county != 'Apple Valley']
data = data[data.city_or_county != 'Appleton']
data = data[data.city_or_county != 'Arcadia']
data = data[data.city_or_county != 'Arcata']
data = data[data.city_or_county != 'Ardmore']
data = data[data.city_or_county != 'Arlington']
data = data[data.city_or_county != 'Armstrong']
data = data[data.city_or_county != 'Artesia']
data = data[data.city_or_county != 'Arvada']
data = data[data.city_or_county != 'Arverne (Queens)']
data = data[data.city_or_county != 'Arvin']
data = data[data.city_or_county != 'Asheboro']
data = data[data.city_or_county != 'Asheville']
data = data[data.city_or_county != 'Ashtabula']
data = data[data.city_or_county != 'Astor']
data = data[data.city_or_county != 'Athens']
data = data[data.city_or_county != 'Auburn']
data = data[data.city_or_county != 'Aurora']
data = data[data.city_or_county != 'Aurora (Centennial)']
data = data[data.city_or_county != 'Winston Salem (Winstone_salem)']
data = data[data.city_or_county != 'Winston_Salem']
data = data[data.city_or_county != 'Winton']
data = data[data.city_or_county != 'Woodburn']
data = data[data.city_or_county != 'Woodlawn']
data = data[data.city_or_county != 'Woodridge']
data = data[data.city_or_county != 'Wooten']
data = data[data.city_or_county != 'Wyandanch']
data = data[data.city_or_county != 'Wyoming']
data = data[data.city_or_county != 'Yakima']
data = data[data.city_or_county != 'Yoncalla']
data = data[data.city_or_county != 'York']
data = data[data.city_or_county != 'Winston Salem']
data = data[data.city_or_county != 'Winston Salem (Winston_Salem)']
data = data[data.city_or_county != 'Wilmington']
data = data[data.city_or_county != 'Wimauma']
data = data[data.city_or_county != 'Wimberley']
data = data[data.city_or_county != 'Winchester']
data = data[data.city_or_county != 'Windsor']
data = data[data.city_or_county != 'Wichita Falls']
data = data[data.city_or_county != 'Willards']
data = data[data.city_or_county != 'Williamsburg (Savoy)']
data = data[data.city_or_county != 'Williamsport']
data = data[data.city_or_county != 'Williston']
data = data[data.city_or_county != 'Willowbrook']
data = data[data.city_or_county != 'Winston Salem (Winston-Salem)']
data = data[data.city_or_county != 'Whitehall']
data = data[data.city_or_county != 'Whitehouse']
data = data[data.city_or_county != 'Whitestown']
data = data[data.city_or_county != 'Whiteville']
data = data[data.city_or_county != 'Whiting']
data = data[data.city_or_county != 'West Palm Beach']
data = data[data.city_or_county != 'Westerville']
data = data[data.city_or_county != 'Westland']
data = data[data.city_or_county != 'Westminster']
data = data[data.city_or_county != 'Wexford County']
data = data[data.city_or_county != 'Wheatfield']
data = data[data.city_or_county != 'Whittier']
data = data[data.city_or_county != 'Winston Salem (Winston-salem)']
data = data[data.city_or_county != 'Winston-Salem']
data = data[data.city_or_county != 'Washington Navy Yard']
data = data[data.city_or_county != 'Washington Park']
data = data[data.city_or_county != 'Wastonville']
data = data[data.city_or_county != 'Waukegan']
data = data[data.city_or_county != 'Waxahachie']
data = data[data.city_or_county != 'Webster']
data = data[data.city_or_county != 'Waukegan']
data = data[data.city_or_county != 'Weldon']
data = data[data.city_or_county != 'Wellington (Topaz Ranch Estates)']
data = data[data.city_or_county != 'Wellston']
data = data[data.city_or_county != 'Wendell']
data = data[data.city_or_county != 'Walnut Park']
data = data[data.city_or_county != 'Walton']
data = data[data.city_or_county != 'Wapato']
data = data[data.city_or_county != 'Warren']
data = data[data.city_or_county != 'Warrenton']
data = data[data.city_or_county != 'Washington']
data = data[data.city_or_county != 'Watsonville']
data = data[data.city_or_county != 'Welasco']
data = data[data.city_or_county != 'Waco']
data = data[data.city_or_county != 'Wadesboro']
data = data[data.city_or_county != 'Wagram']
data = data[data.city_or_county != 'Waldorf']
data = data[data.city_or_county != 'Walker']
data = data[data.city_or_county != 'Walker (county)']
data = data[data.city_or_county != 'Ventura']
data = data[data.city_or_county != 'Vero Beach']
data = data[data.city_or_county != 'Victorville']
data = data[data.city_or_county != 'Victorville (Spring Valley Lake)']
data = data[data.city_or_county != 'Visalia']
data = data[data.city_or_county != 'Walkertown']
data = data[data.city_or_county != 'Walla Walla']
data = data[data.city_or_county != 'Weslaco']
data = data[data.city_or_county != 'Wesley Chapel']
data = data[data.city_or_county != 'Vallejo']
data = data[data.city_or_county != 'Van Nuys']
data = data[data.city_or_county != 'Vanceboro']
data = data[data.city_or_county != 'Vancouver']
data = data[data.city_or_county != 'Twinsburg']
data = data[data.city_or_county != 'Tyler']
data = data[data.city_or_county != 'Tyler (county)']
data = data[data.city_or_county != 'Umatilla']
data = data[data.city_or_county != 'Union City']
data = data[data.city_or_county != 'Uniontown']
data = data[data.city_or_county != 'Universal City']
data = data[data.city_or_county != 'Upper Marlboro (Largo)']
data = data[data.city_or_county != 'Utica']
data = data[data.city_or_county != 'Veneta']
data = data[data.city_or_county != 'Venice']
data = data[data.city_or_county != 'Aurora']
data = data[data.city_or_county != 'Tulsa']
data = data[data.city_or_county != 'Turner']
data = data[data.city_or_county != 'Turtle Creek']
data = data[data.city_or_county != 'Tucumcari']
data = data[data.city_or_county != 'Tulare']
data = data[data.city_or_county != 'Turtletown']
data = data[data.city_or_county != 'West Allis']
data = data[data.city_or_county != 'West Covina']
data = data[data.city_or_county != 'West Frankfort']
data = data[data.city_or_county != 'West Hollywood']
data = data[data.city_or_county != 'Troy']
data = data[data.city_or_county != 'Troutdale']
data = data[data.city_or_county != 'West Lafayette']
data = data[data.city_or_county != 'Woodland']
data = data[data.city_or_county != 'Yuba (county)']
data = data[data.city_or_county != 'Yuba City']
data = data[data.city_or_county != 'Yuma']
data = data[data.city_or_county != 'Zanesville']
data = data[data.city_or_county != 'Zavalla']
data = data[data.city_or_county != 'Zebulon']
data = data[data.city_or_county != 'Zion']
data = data[data.city_or_county != 'Glendale']
data = data[data.city_or_county != 'Gilbert']
data = data[data.city_or_county != 'Tempe (Guadalupe)']
data = data[data.city_or_county != 'Tolleson']
data = data[data.city_or_county != 'Pearce (Sunizona)']
data = data[data.city_or_county != 'Goodyear']
data = data[data.city_or_county != 'Chandler']
data = data[data.city_or_county != 'Mesa']
data = data[data.city_or_county != 'Avondale']
data = data[data.city_or_county != 'Madison']
data = data[data.city_or_county != 'Flagstaff']
data = data[data.city_or_county != 'Tempe']
data = data[data.city_or_county != 'Saratoga']
data = data[data.city_or_county != 'Fitchburg']
data = data[data.city_or_county != 'Sparta']
data = data[data.city_or_county != 'Beloit']
data = data[data.city_or_county != 'Hawthorne']
data = data[data.city_or_county != 'Lorain']
data = data[data.city_or_county != 'Greensboro']
data = data[data.city_or_county != 'Chattanooga']
data = data[data.city_or_county != 'Springfield']
data = data[data.city_or_county != 'Midvale']
data = data[data.city_or_county != 'Orange (county)']
data = data[data.city_or_county != 'Los banos']
data = data[data.city_or_county != 'Los Banoss']
data = data[data.city_or_county != 'Oceanside']
data = data[data.city_or_county != 'Mohawk']
data = data[data.city_or_county != 'Brooklyn']
data = data[data.city_or_county != 'Merced (county)']
data = data[data.city_or_county != 'Long Beach']
data = data[data.city_or_county != 'Lexington']
data = data[data.city_or_county != 'Manchester']
data = data[data.city_or_county != 'Jackson']
data = data[data.city_or_county != 'Bean Station']
data = data[data.city_or_county != 'Bakersfield']
data = data[data.city_or_county != 'Flint']
data = data[data.city_or_county != 'Santa Monica']
data = data[data.city_or_county != 'Three Rivers']
data = data[data.city_or_county != 'Pontiac']
data = data[data.city_or_county != 'Stockton']
data = data[data.city_or_county != 'Pompano Beach']
data = data[data.city_or_county != 'Rockford']
data = data[data.city_or_county != 'Charlotte']
data = data[data.city_or_county != 'Greensburg']
data = data[data.city_or_county != 'Oakland']
data = data[data.city_or_county != 'Salinas']
data = data[data.city_or_county != 'Saylorsburg']
data = data[data.city_or_county != 'Henderson']
data = data[data.city_or_county != 'Inglewood']
data = data[data.city_or_county != 'Aurora']
data = data[data.city_or_county != 'Lake Butler']
data = data[data.city_or_county != 'Gary']
data = data[data.city_or_county != 'Muskegon']
data = data[data.city_or_county != 'Fort Wayne']
data = data[data.city_or_county != 'Brewster']
data = data[data.city_or_county != 'Hemet']
data = data[data.city_or_county != 'Taylorville']
data = data[data.city_or_county != 'San Marcos']
data = data[data.city_or_county != 'Los Banos']
data = data[data.city_or_county != 'Miami']
data = data[data.city_or_county != 'Souther Pines']
data = data[data.city_or_county != 'Radcliff']
data = data[data.city_or_county != 'Thousand Oaks']
data = data[data.city_or_county != 'Hollywood (Miramar)']
data = data[data.city_or_county != 'Great Mills']
data = data[data.city_or_county != 'Daytona Beach']
data = data[data.city_or_county != 'Cypress']
data = data[data.city_or_county != 'Garner']
data = data[data.city_or_county != 'Blanchard']
data = data[data.city_or_county != 'Mount Vernon']
data = data[data.city_or_county != 'Buckley']
data = data[data.city_or_county != 'Canton']
data = data[data.city_or_county != 'Plant City']
data = data[data.city_or_county != 'Colorado Springs']
data = data[data.city_or_county != 'Champaign']
data = data[data.city_or_county != 'Fort Sumner']
data = data[data.city_or_county != 'Harrisburg']
data = data[data.city_or_county != 'Bloomington']
data = data[data.city_or_county != 'Georgetown']
data = data[data.city_or_county != 'Sanford']
data = data[data.city_or_county != 'Olivehurst']
data = data[data.city_or_county != 'Plano']
data = data[data.city_or_county != 'Santa Rosa']
data = data[data.city_or_county != 'Terre Haute']
data = data[data.city_or_county != 'Gladewater']
data = data[data.city_or_county != 'Steubenville']
data = data[data.city_or_county != 'Joliet']
data = data[data.city_or_county != 'Pomona']
data = data[data.city_or_county != 'Mancelona']
data = data[data.city_or_county != 'Coarsegold']
data = data[data.city_or_county != 'Croydon']
data = data[data.city_or_county != 'Maxton']
data = data[data.city_or_county != 'Crisfield']
data = data[data.city_or_county != 'Lindenhurst']
data = data[data.city_or_county != 'Lebanon']
data = data[data.city_or_county != 'Toledo']
data = data[data.city_or_county != 'Kingsport']
data = data[data.city_or_county != 'Fayetteville']
data = data[data.city_or_county != 'Salt Lake City (South Salt Lake)']
data = data[data.city_or_county != 'Fernley']
data = data[data.city_or_county != 'Fullerton']
data = data[data.city_or_county != 'Homestead (Florida City)']
data = data[data.city_or_county != 'Brookville']
data = data[data.city_or_county != 'Spring']
data = data[data.city_or_county != 'Pembroke']
data = data[data.city_or_county != 'Spiceland']
data = data[data.city_or_county != 'Grand Junction']
data = data[data.city_or_county != 'Montrose (county)']
data = data[data.city_or_county != 'Durham']
data = data[data.city_or_county != 'Cincinnati (North College Hill)']
data = data[data.city_or_county != 'Rochester']
data = data[data.city_or_county != 'Orlando']
data = data[data.city_or_county != 'Fort Lauderdale (Oakland Park)']
data = data[data.city_or_county != 'Lakeland']
data = data[data.city_or_county != 'Hammon']
data = data[data.city_or_county != 'Dayton']
data = data[data.city_or_county != 'Rock Island']
data = data[data.city_or_county != 'Cleveland']
data = data[data.city_or_county != 'Murphysboro']
data = data[data.city_or_county != 'Reno']
data = data[data.city_or_county != 'Tacoma']
data = data[data.city_or_county != 'Fort Lauderdale']
data = data[data.city_or_county != 'Orlando (Orlo Vista)']
data = data[data.city_or_county != 'Tampa']
data = data[data.city_or_county != 'Baytown']
data = data[data.city_or_county != 'Melbourne']
data = data[data.city_or_county != 'Syracuse']
data = data[data.city_or_county != 'Aurora']
data = data[data.city_or_county != 'Southern Pines']
data = data[data.city_or_county != 'East Saint Louis']
data = data[data.city_or_county != 'Pittsburgh']
data = data[data.city_or_county != 'Fort Collins']
data = data[data.city_or_county != 'Brown Summit']
data = data[data.city_or_county != 'Saint Joseph']
data = data[data.city_or_county != 'Killeen']
data = data[data.city_or_county != 'Bastrop']
data = data[data.city_or_county != 'Menasha']
data = data[data.city_or_county != 'Fort Hood']
data = data[data.city_or_county != 'Aurora']
data = data[data.city_or_county != 'Goleta (Isla Vista)']
data = data[data.city_or_county != 'Essex']
data = data[data.city_or_county != 'Hermiston']
data = data[data.city_or_county != 'District Heights']
data = data[data.city_or_county != 'San Bernardino']
data = data[data.city_or_county != 'Bowie']
data = data[data.city_or_county != 'Franklin']
data = data[data.city_or_county != 'San Angelo']
data = data[data.city_or_county != 'Beachwood (Warrensville Heights)']
data = data[data.city_or_county != 'Olympia']
data = data[data.city_or_county != 'Crestview']
data = data[data.city_or_county != 'Mcallen']
data = data[data.city_or_county != 'Fontana']
data = data[data.city_or_county != 'Canonsburg']
data = data[data.city_or_county != 'Browns Summit']
data = data[data.city_or_county != 'Jupiter']
data = data[data.city_or_county != 'Pasadena']
data = data[data.city_or_county != 'Mukilteo']
data = data[data.city_or_county != 'Hickory']
data = data[data.city_or_county != 'Fremont']
data = data[data.city_or_county != 'Lake Worth (Lantana)']
data = data[data.city_or_county != 'Beaumont']
data = data[data.city_or_county != 'Nokomis']
data = data[data.city_or_county != 'Capitol Heights']
data = data[data.city_or_county != 'Dwight']
data = data[data.city_or_county != 'Marysville']
data = data[data.city_or_county != 'Kalamazoo']
data = data[data.city_or_county != 'Corning']
data = data[data.city_or_county != 'Roseburg']
data = data[data.city_or_county != 'Pompano Beach (Parkland)']
data = data[data.city_or_county != 'Sutherland Springs']
data = data[data.city_or_county != 'New Port Richey']
data = data[data.city_or_county != 'Cabarrus County']
data = data[data.city_or_county != 'Hope Mills']
data = data[data.city_or_county != 'Edgewood']
data = data[data.city_or_county != 'Delaware']
data = data[data.city_or_county != 'Lancaster']
data = data[data.city_or_county != 'Hayward']
data = data[data.city_or_county != 'Dade City']
data = data[data.city_or_county != 'Sebring']
data = data[data.city_or_county != 'Palm Springs']
data = data[data.city_or_county != 'Richmond']
data = data[data.city_or_county != 'Newaygo']
data = data[data.city_or_county != 'Muskegon (Muskegon Heights)']
data = data[data.city_or_county != 'Riverside (Jurupa Valley)']
data = data[data.city_or_county != 'Cleburne']
data = data[data.city_or_county != 'Dearborn Heights']
data = data[data.city_or_county != 'Bronx']
data = data[data.city_or_county != 'Gates']
data = data[data.city_or_county != 'Orange County']
data = data[data.city_or_county != 'College Station']
data = data[data.city_or_county != 'Pensacola']
data = data[data.city_or_county != 'High Point']
data = data[data.city_or_county != 'Edinburg']
data = data[data.city_or_county != 'Littleton (Highlands Ranch)']
data = data[data.city_or_county != 'Chelsea']
data = data[data.city_or_county != 'Modesto']
data = data[data.city_or_county != 'Hamilton']
data = data[data.city_or_county != 'Dyersburg']
data = data[data.city_or_county != 'Cincinnati']
data = data[data.city_or_county != 'Grand Rapids']
data = data[data.city_or_county != 'Calumet City']
data = data[data.city_or_county != 'Benton']
data = data[data.city_or_county != 'Fort Myers']
data = data[data.city_or_county != 'Ocala']
data = data[data.city_or_county != 'Newburgh']
data = data[data.city_or_county != 'Pittsburgh (Homewood)']
data = data[data.city_or_county != 'Macomb (Macomb Township)']
data = data[data.city_or_county != 'Kingman']
data = data[data.city_or_county != 'Queens']
data = data[data.city_or_county != 'Marshall']
data = data[data.city_or_county != 'Sullivan County']
data = data[data.city_or_county != 'Harbor City']
data = data[data.city_or_county != 'Garden City']
data = data[data.city_or_county != 'South Bend']
data = data[data.city_or_county != 'New Bern']
data = data[data.city_or_county != 'Silver Spring']
data = data[data.city_or_county != 'Johnson City']
data = data[data.city_or_county != 'Compton']
data = data[data.city_or_county != 'North Plains']
data = data[data.city_or_county != 'El Paso County']
data = data[data.city_or_county != 'Linden']
data = data[data.city_or_county != 'Buffalo']
data = data[data.city_or_county != 'Odessa']
data = data[data.city_or_county != 'El Cajon']
data = data[data.city_or_county != 'El Monte']
data = data[data.city_or_county != 'Castroville']
data = data[data.city_or_county != 'Holly Springs']
data = data[data.city_or_county != 'Cape Coral']
data = data[data.city_or_county != 'Bartlesville']
data = data[data.city_or_county != 'Lookout Valley']
data = data[data.city_or_county != 'Donna']
data = data[data.city_or_county != 'Boynton Beach']
data = data[data.city_or_county != 'Perry']
data = data[data.city_or_county != 'Laredo']
data = data[data.city_or_county != 'Jonesville']
data = data[data.city_or_county != 'Bowie (county)']
data = data[data.city_or_county != 'Little Orleans']
data = data[data.city_or_county != 'Chicago']
data = data[data.city_or_county != 'Silver Springs']
data = data[data.city_or_county != 'Evansville']
data = data[data.city_or_county != 'Gastonia']
data = data[data.city_or_county != 'Goodlettsville']
data = data[data.city_or_county != 'Staten Island']
data = data[data.city_or_county != 'New Paris']
data = data[data.city_or_county != 'Cordova']
data = data[data.city_or_county != 'Park Forest']
data = data[data.city_or_county != 'Trosper']
data = data[data.city_or_county != 'Rufle']
data = data[data.city_or_county != 'Somerville']
data = data[data.city_or_county != 'Bremerton']
data = data[data.city_or_county != 'Manteca']
data = data[data.city_or_county != 'Kittrell']
data = data[data.city_or_county != 'Roscommon (county)']
data = data[data.city_or_county != 'Fritch']
data = data[data.city_or_county != 'Rufe']
data = data[data.city_or_county != 'Tallahassee']
data = data[data.city_or_county != 'Galveston']
data = data[data.city_or_county != 'Jay']
data = data[data.city_or_county != 'River Forest']
data = data[data.city_or_county != 'Casselberry']
data = data[data.city_or_county != 'Boca Raton']
data = data[data.city_or_county != 'Hollywood']
data = data[data.city_or_county != 'Putnam (county)']
data = data[data.city_or_county != 'Hallandale Beach']
data = data[data.city_or_county != 'Nanjemoy']
data = data[data.city_or_county != 'Dundalk']
data = data[data.city_or_county != 'Moreno Valley']
data = data[data.city_or_county != 'Prairie View']
data = data[data.city_or_county != 'Honey Brook']
data = data[data.city_or_county != 'Melrose Park']
data = data[data.city_or_county != 'Miami-dade']
data = data[data.city_or_county != 'Littleton (Lakewood)']
data = data[data.city_or_county != 'Temple']
data = data[data.city_or_county != 'Running Springs']
data = data[data.city_or_county != 'Oroville']
data = data[data.city_or_county != 'Coachella']
data = data[data.city_or_county != 'Belle Glade']
data = data[data.city_or_county != 'Planada']
data = data[data.city_or_county != 'Hidalgo County']
data = data[data.city_or_county != 'Shelbyville']
data = data[data.city_or_county != 'D Hanis']
data = data[data.city_or_county != 'Jacksonville Beach']
data = data[data.city_or_county != 'Florida City']
data = data[data.city_or_county != 'La Joya']
data = data[data.city_or_county != 'East Lansing']
data = data[data.city_or_county != 'North Miami']
data = data[data.city_or_county != 'Norman']
data = data[data.city_or_county != 'Reading']
data = data[data.city_or_county != 'Glen Saint Mary (Glen St Mary)']
data = data[data.city_or_county != 'Paoli']
data = data[data.city_or_county != 'Pittsburgh (Brentwood)']
data = data[data.city_or_county != 'Bensalem']
data = data[data.city_or_county != 'Mcminnville']
data = data[data.city_or_county != 'Titusville']
data = data[data.city_or_county != 'Brockport']
data = data[data.city_or_county != 'Salt Lake City (West Valley City)']
data = data[data.city_or_county != 'Spring Hill']
data = data[data.city_or_county != 'Sparks (Spanish Springs)']
data = data[data.city_or_county != 'Levy County']
data = data[data.city_or_county != 'Rocky Mount']
data = data[data.city_or_county != 'Jal']
data = data[data.city_or_county != 'New Florence']
data = data[data.city_or_county != 'Catonsville']
data = data[data.city_or_county != 'Bailey']
data = data[data.city_or_county != 'Superior']
data = data[data.city_or_county != 'Palm Beach Gardens (Riviera Beach)']
data = data[data.city_or_county != 'Livingston']
data = data[data.city_or_county != 'Cottonwood']
data = data[data.city_or_county != 'Baldwin']
data = data[data.city_or_county != 'Fort Pierce']
data = data[data.city_or_county != 'South Gate']
data = data[data.city_or_county != 'Shamoki']
data = data[data.city_or_county != 'Missouri City']
data = data[data.city_or_county != 'Charleston']
data = data[data.city_or_county != 'Daly City']
data = data[data.city_or_county != 'East Chicago']
data = data[data.city_or_county != 'Peoria']
data = data[data.city_or_county != 'North Port']
data = data[data.city_or_county != 'Lake Lynn']
data = data[data.city_or_county != 'Ector County']
data = data[data.city_or_county != 'Harvey']
data = data[data.city_or_county != 'East St. Louis']
data = data[data.city_or_county != 'Lawtwon']
data = data[data.city_or_county != 'Cambridge']
data = data[data.city_or_county != 'Cumberland']
data = data[data.city_or_county != 'Clairton']
data = data[data.city_or_county != 'Greeley']
data = data[data.city_or_county != 'Hagerstown']
data = data[data.city_or_county != 'Miami Beach']
data = data[data.city_or_county != 'Fillmore']
data = data[data.city_or_county != 'North Hollywood']
data = data[data.city_or_county != 'Robbins']
data = data[data.city_or_county != 'Pittsburgh (Churchill)']
data = data[data.city_or_county != 'Raleigh']
data = data[data.city_or_county != 'Middletown']
data = data[data.city_or_county != 'Los Lunas']
data = data[data.city_or_county != 'Covington']
data = data[data.city_or_county != 'Banning']
data = data[data.city_or_county != 'Fairchance']
data = data[data.city_or_county != 'Carson']
data = data[data.city_or_county != 'Huntington Station']
data = data[data.city_or_county != 'Graham']
data = data[data.city_or_county != 'Glasgow']
data = data[data.city_or_county != 'Hersperia']
data = data[data.city_or_county != 'Darby']
data = data[data.city_or_county != 'Evans']
data = data[data.city_or_county != 'Michigan City']
data = data[data.city_or_county != 'Euclid']
data = data[data.city_or_county != 'Salt Lake City']
data = data[data.city_or_county != 'Hueysville']
data = data[data.city_or_county != 'Bend (Sunriver)']
data = data[data.city_or_county != 'Covina']
data = data[data.city_or_county != 'Seaside (Sand City)']
data = data[data.city_or_county != 'Chico']
data = data[data.city_or_county != 'Cleveland (Cleveland Heights)']
data = data[data.city_or_county != 'Bowling Green']
data = data[data.city_or_county != 'Crosby']
data = data[data.city_or_county != 'Linesville']
data = data[data.city_or_county != 'Palmetto']
data = data[data.city_or_county != 'Puyallup']
data = data[data.city_or_county != 'Spanish Fork']
data = data[data.city_or_county != 'Belltown']
data = data[data.city_or_county != 'Eureka']
data = data[data.city_or_county != 'Corpus Christi']
data = data[data.city_or_county != 'Lima']
data = data[data.city_or_county != 'Paso Robles']
data = data[data.city_or_county != 'Tabor City']
data = data[data.city_or_county != 'Pittsburgh']
data = data[data.city_or_county != 'Gaithersburg']
data = data[data.city_or_county != 'Everett']
data = data[data.city_or_county != 'Garden Grove']
data = data[data.city_or_county != 'Cahokia']
data = data[data.city_or_county != 'Bonney Lake']
data = data[data.city_or_county != 'Napa']
data = data[data.city_or_county != 'Cocoa']
data = data[data.city_or_county != 'Cerritos']
data = data[data.city_or_county != 'Indian Hills']
data = data[data.city_or_county != 'Porterville']
data = data[data.city_or_county != 'Greenville']
data = data[data.city_or_county != 'Seattle (Seatac)']
data = data[data.city_or_county != 'Sauk Village']
data = data[data.city_or_county != 'Enid']
data = data[data.city_or_county != 'Salisbury']
data = data[data.city_or_county != 'Berea']
data = data[data.city_or_county != 'Dry Ridge']
data = data[data.city_or_county != 'Gainsville']
data = data[data.city_or_county != 'Bellwood']
data = data[data.city_or_county != 'Deltona']
data = data[data.city_or_county != 'Monongahela']
data = data[data.city_or_county != 'Saint Petersburg (St Petersburg)']
data = data[data.city_or_county != 'Burlingston']
data = data[data.city_or_county != 'Onslow County']
data = data[data.city_or_county != 'Rio Rancho']
data = data[data.city_or_county != 'Bethesda']
data = data[data.city_or_county != 'Noblesville']
data = data[data.city_or_county != 'North Hills']
data = data[data.city_or_county != 'Red Springs']
data = data[data.city_or_county != 'Lawndale']
data = data[data.city_or_county != 'Paint Lick']
data = data[data.city_or_county != 'Clarksville']
data = data[data.city_or_county != 'Gardena']
data = data[data.city_or_county != 'Scotland Neck']
data = data[data.city_or_county != 'Gladwin']
data = data[data.city_or_county != 'Lawrence']
data = data[data.city_or_county != 'Holley']
data = data[data.city_or_county != 'Marianna']
data = data[data.city_or_county != 'Hammond']
data = data[data.city_or_county != 'Brownsburg']
data = data[data.city_or_county != 'District Heights (Forestville)']
data = data[data.city_or_county != 'San Gabriel']
data = data[data.city_or_county != 'Kissimmee (Poinciana)']
data = data[data.city_or_county != 'East Palo Alto']
data = data[data.city_or_county != 'Miami-Dade']
data = data[data.city_or_county != 'Santa Ana']
data = data[data.city_or_county != 'Lubbock']
data = data[data.city_or_county != 'Bradenton']
data = data[data.city_or_county != 'Brunswick']
data = data[data.city_or_county != 'Orland']
data = data[data.city_or_county != 'Lumberton']
data = data[data.city_or_county != 'Redford Chater Township']
data = data[data.city_or_county != 'Bainbridge']
data = data[data.city_or_county != 'Harris (county)']
data = data[data.city_or_county != 'Saint Petersburg']
data = data[data.city_or_county != 'Chester']
data = data[data.city_or_county != 'Empire']
data = data[data.city_or_county != 'Holland']
data = data[data.city_or_county != 'Estero']
data = data[data.city_or_county != 'Kinston']
data = data[data.city_or_county != 'Texarkana']
data = data[data.city_or_county != 'Homestead']
data = data[data.city_or_county != 'De Ruyter (Deruyter)']
data = data[data.city_or_county != 'North East']
data = data[data.city_or_county != 'Raymondville']
data = data[data.city_or_county != 'Panola']
data = data[data.city_or_county != 'Bristol']
data = data[data.city_or_county != 'Indian Springs']
data = data[data.city_or_county != 'Dekalb (DeKalb)']
data = data[data.city_or_county != 'Belton']
data = data[data.city_or_county != 'Panorama City']
data = data[data.city_or_county != 'Fort Lauderdale (Tamarac)']
data = data[data.city_or_county != 'Central Islip']
data = data[data.city_or_county != 'Norwalk']
data = data[data.city_or_county != 'Middle River']
data = data[data.city_or_county != 'Signal Hill']
data = data[data.city_or_county != 'Schenectady']
data = data[data.city_or_county != 'New Castle']
data = data[data.city_or_county != 'Azusa']
data = data[data.city_or_county != 'Desert Hot Springs']
data = data[data.city_or_county != 'La Marque']
data = data[data.city_or_county != 'Garland']
data = data[data.city_or_county != 'Gypsum']
data = data[data.city_or_county != 'Palmyra']
data = data[data.city_or_county != 'Newton']
data = data[data.city_or_county != 'Pharr']
data = data[data.city_or_county != 'Merced']
data = data[data.city_or_county != 'Portage']
data = data[data.city_or_county != 'Lansing']
data = data[data.city_or_county != 'Littleton']
data = data[data.city_or_county != 'Katy']
data = data[data.city_or_county != 'Milford']
data = data[data.city_or_county != 'Mc Kees Rocks (Mckees Rocks)']
data = data[data.city_or_county != 'Centralia']
data = data[data.city_or_county != 'Brockton']
data = data[data.city_or_county != 'Sunnyvale']
data = data[data.city_or_county != 'Enfield']
data = data[data.city_or_county != 'Channelview']
data = data[data.city_or_county != 'Hazleton']
data = data[data.city_or_county != 'Hillsboro']
data = data[data.city_or_county != 'Limestone']
data = data[data.city_or_county != 'Leesburg']
data = data[data.city_or_county != 'Farmington']
data = data[data.city_or_county != 'Freeport']
data = data[data.city_or_county != 'Sandy']
data = data[data.city_or_county != 'Guffey']
data = data[data.city_or_county != 'Poughskeepsie']
data = data[data.city_or_county != 'Delano']
data = data[data.city_or_county != 'Magna']
data = data[data.city_or_county != 'Cleveland (Richmond Heights)']
data = data[data.city_or_county != 'Newark']
data = data[data.city_or_county != 'Corcoran']
data = data[data.city_or_county != 'College Park']
data = data[data.city_or_county != 'Thornton']
data = data[data.city_or_county != 'Molalla']
data = data[data.city_or_county != 'Chicago Heights']
data = data[data.city_or_county != 'Knoxville']
data = data[data.city_or_county != 'Laurel']
data = data[data.city_or_county != 'Livermore']
data = data[data.city_or_county != 'Mckeesport']
data = data[data.city_or_county != 'Bellflower']
data = data[data.city_or_county != 'Tracy City']
data = data[data.city_or_county != 'Hyattsville (Landover)']
data = data[data.city_or_county != 'Trabuco Canyon']
data = data[data.city_or_county != 'Elyria']
data = data[data.city_or_county != 'Brazil']
data = data[data.city_or_county != 'El Cerrito']
data = data[data.city_or_county != 'Salt Lake City (Holladay)']
data = data[data.city_or_county != 'North Las Vegas']
data = data[data.city_or_county != 'Federal Way']
data = data[data.city_or_county != 'Braddock']
data = data[data.city_or_county != 'Modoc (county)']
data = data[data.city_or_county != 'Braddock (Rankin)']
data = data[data.city_or_county != 'Bayboro']
data = data[data.city_or_county != 'Bexar (county)']
data = data[data.city_or_county != 'Pacoima']
data = data[data.city_or_county != 'Bolivar']
data = data[data.city_or_county != 'Selma']
data = data[data.city_or_county != 'Corvallis']
data = data[data.city_or_county != 'Greeneville']
data = data[data.city_or_county != 'Pittsburg']
data = data[data.city_or_county != 'Elizabeth City']
data = data[data.city_or_county != 'Mojave']
data = data[data.city_or_county != 'Euless']
data = data[data.city_or_county != 'Lake WOrth']
data = data[data.city_or_county != 'Highland Park']
data = data[data.city_or_county != 'La Quinta']
data = data[data.city_or_county != 'Shamokin']
data = data[data.city_or_county != 'Rainier']
data = data[data.city_or_county != 'Damascus']
data = data[data.city_or_county != 'Gresham']
data = data[data.city_or_county != 'Cottage Grove']
data = data[data.city_or_county != 'Bellport']
data = data[data.city_or_county != "O'brien"]
data = data[data.city_or_county != 'Far Rockaway']
data = data[data.city_or_county != 'Emeryville']
data = data[data.city_or_county != 'Rock Falls']
data = data[data.city_or_county != 'Burlington']
data = data[data.city_or_county != 'Oak Harbor']
data = data[data.city_or_county != 'Danville']
data = data[data.city_or_county != 'Behlehem']
data = data[data.city_or_county != 'Temple Hills']
data = data[data.city_or_county != 'Huntington Park']
data = data[data.city_or_county != 'Osceola Mills']
data = data[data.city_or_county != 'Corona (Queens)']
data = data[data.city_or_county != 'Hesperia']
data = data[data.city_or_county != 'Pine Hills']
data = data[data.city_or_county != 'Roswell']
data = data[data.city_or_county != 'Orosi']
data = data[data.city_or_county != 'Hatch']
data = data[data.city_or_county != 'Miami Gardens']
data = data[data.city_or_county != 'Carlsbad']
data = data[data.city_or_county != 'Beaverton']
data = data[data.city_or_county != 'Bolingbrook']
data = data[data.city_or_county != 'Mooresville']
data = data[data.city_or_county != 'Saginaw']
data = data[data.city_or_county != 'Cincinnati (Colerain Township)']
data = data[data.city_or_county != 'Orlando (Pine Hills)']
data = data[data.city_or_county != 'Fairmont']
data = data[data.city_or_county != 'Redford Chater Township']
data = data[data.city_or_county != 'Bermuda Dunes']
data = data[data.city_or_county != 'Jefferson']
data = data[data.city_or_county != 'Lovelock']
data = data[data.city_or_county != 'Street']
data = data[data.city_or_county != 'Oregon City']
data = data[data.city_or_county != 'Ravenna']
data = data[data.city_or_county != 'Mission (Palmview)']
data = data[data.city_or_county != 'Hialeah']
data = data[data.city_or_county != 'Martinez (Pancheco)']
data = data[data.city_or_county != 'Leland']
data = data[data.city_or_county != 'Lehigh Acres']
data = data[data.city_or_county != 'Levittown']
data = data[data.city_or_county != 'Shawnee']
data = data[data.city_or_county != 'Stafford']
data = data[data.city_or_county != 'Cleveland (Garfield Heights)']
data = data[data.city_or_county != 'Saint Cloud']
data = data[data.city_or_county != 'Converse']
data = data[data.city_or_county != 'Fort George G Meade (Fort Meade)']
data = data[data.city_or_county != 'Harker Heights']
data = data[data.city_or_county != 'Inkster']
data = data[data.city_or_county != 'Hollister']
data = data[data.city_or_county != 'King City']
data = data[data.city_or_county != 'Campbellsville']
data = data[data.city_or_county != 'Salt Lake City (Kearns)']
data = data[data.city_or_county != 'Edinboro']
data = data[data.city_or_county != 'Redondo Beach']
data = data[data.city_or_county != 'Pittsfield']
data = data[data.city_or_county != 'Mcalester']
data = data[data.city_or_county != 'Maud']
data = data[data.city_or_county != 'Madison (county)']
data = data[data.city_or_county != 'Phoenixville']
data = data[data.city_or_county != 'Christian County']
data = data[data.city_or_county != 'Renton']
data = data[data.city_or_county != 'Sherwood']
data = data[data.city_or_county != 'Dayton (Trotwood)']
data = data[data.city_or_county != 'Monroe County']
data = data[data.city_or_county != 'Monrovia']
data = data[data.city_or_county != 'Perris']
data = data[data.city_or_county != 'Matthews']
data = data[data.city_or_county != 'Sylvania Township']
data = data[data.city_or_county != 'Delhi']
data = data[data.city_or_county != 'Montfort']
data = data[data.city_or_county != 'Monticello']
data = data[data.city_or_county != 'Harrison']
data = data[data.city_or_county != 'Frayser']
data = data[data.city_or_county != 'Tawas City']
data = data[data.city_or_county != 'Lincoln City']
data = data[data.city_or_county != 'North Ogden']
data = data[data.city_or_county != 'Ellwood City']
data = data[data.city_or_county != 'Trenton']
data = data[data.city_or_county != 'Cleveland Heights']
data = data[data.city_or_county != 'South San Francisco']
data = data[data.city_or_county != 'Kankakee']
data = data[data.city_or_county != 'Sarasota']
data = data[data.city_or_county != 'Harris County']
data = data[data.city_or_county != 'National City']
data = data[data.city_or_county != 'Smith (county)']
data = data[data.city_or_county != 'Miami (Kendall)']
data = data[data.city_or_county != 'San Pedro']
data = data[data.city_or_county != 'Paducah (Reidland)']
data = data[data.city_or_county != 'Crawford']
data = data[data.city_or_county != 'Gainesville']
data = data[data.city_or_county != 'Elkhart']
data = data[data.city_or_county != 'Tiffin']
data = data[data.city_or_county != 'Murfreesboro']
data = data[data.city_or_county != 'Riviera Beach']
data = data[data.city_or_county != 'Oxnard']
data = data[data.city_or_county != 'Liverpool (Salina)']
data = data[data.city_or_county != 'Monee']
data = data[data.city_or_county != 'East Falmouth']
data = data[data.city_or_county != 'Binghamton']
data = data[data.city_or_county != 'Chestertown']
data = data[data.city_or_county != 'Erwin']
data = data[data.city_or_county != 'Canadian (county)']
data = data[data.city_or_county != 'Oak Grove']
data = data[data.city_or_county != 'Ken (county)']
data = data[data.city_or_county != 'Eastpointe']
data = data[data.city_or_county != 'Greenfield']
data = data[data.city_or_county != 'Eddyville']
data = data[data.city_or_county != 'Bladenboro']
data = data[data.city_or_county != 'Neenah']
data = data[data.city_or_county != 'Pasco']
data = data[data.city_or_county != 'Pampa']
data = data[data.city_or_county != 'Cedar Hill']
data = data[data.city_or_county != 'Boyle Heights']
data = data[data.city_or_county != 'Kissimmee']
data = data[data.city_or_county != 'Skokie']
data = data[data.city_or_county != 'Riverside']
data = data[data.city_or_county != 'Ephrata']
data = data[data.city_or_county != 'Kent (county)']
data = data[data.city_or_county != 'Owensboro']
data = data[data.city_or_county != 'Pine Ridge']
data = data[data.city_or_county != 'Rogers']
data = data[data.city_or_county != 'Cheltenham']
data = data[data.city_or_county != 'Somerton']
data = data[data.city_or_county != 'Fairfield']
data = data[data.city_or_county != 'Ooltewah']
data = data[data.city_or_county != 'Redlands']
data = data[data.city_or_county != 'Saint Charles']
data = data[data.city_or_county != 'Statesville']
data = data[data.city_or_county != 'Sandusky']
data = data[data.city_or_county != 'Pineville']
data = data[data.city_or_county != 'Indio']
data = data[data.city_or_county != 'Goldsboro']
data = data[data.city_or_county != 'Grand Prairie']
data = data[data.city_or_county != 'Burtonsville']
data = data[data.city_or_county != 'Norristown']
data = data[data.city_or_county != 'Carthage']
data = data[data.city_or_county != 'Clearlake Oaks']
data = data[data.city_or_county != 'Soquel']
data = data[data.city_or_county != 'Seffner']
data = data[data.city_or_county != 'Pueblo']
data = data[data.city_or_county != 'Erie']
data = data[data.city_or_county != 'Coatesville']
data = data[data.city_or_county != 'Salem']
data = data[data.city_or_county != 'Bay County']
data = data[data.city_or_county != 'Raymondville (Santa Monica)']
data = data[data.city_or_county != 'Kaufman']
data = data[data.city_or_county != 'Quincy']
data = data[data.city_or_county != 'Taswell']
data = data[data.city_or_county != 'Hohenwald']
data = data[data.city_or_county != 'Mount Dora']
data = data[data.city_or_county != 'Goshen']
data = data[data.city_or_county != 'Fortuna']
data = data[data.city_or_county != 'Iron (county)']
data = data[data.city_or_county != 'Cltion Township (Chater Twp of Clinton)']
data = data[data.city_or_county != 'Sunnyside']
data = data[data.city_or_county != 'Edgewater']
data = data[data.city_or_county != 'Taunton']
data = data[data.city_or_county != 'Mendota']
data = data[data.city_or_county != 'Pittsburgh (Swissvale)']
data = data[data.city_or_county != 'Montclair']
data = data[data.city_or_county != 'Manatee']
data = data[data.city_or_county != 'Carrick']
data = data[data.city_or_county != 'North Miami Beach']
data = data[data.city_or_county != 'Sand Lake']
data = data[data.city_or_county != 'Evanston']
data = data[data.city_or_county != 'Keizer']
data = data[data.city_or_county != 'Decatur']
data = data[data.city_or_county != 'Reedley']
data = data[data.city_or_county != 'Teague']
data = data[data.city_or_county != 'Nicholasville']
data = data[data.city_or_county != 'Live Oak']
data = data[data.city_or_county != 'Laughlin']
data = data[data.city_or_county != 'Queen City']
data = data[data.city_or_county != 'Cincinnati (Reading)']
data = data[data.city_or_county != 'Green Cove Springs']
data = data[data.city_or_county != 'Dotsero']
data = data[data.city_or_county != 'Poughkeepsie']
data = data[data.city_or_county != 'Ocoee']
data = data[data.city_or_county != 'Naples']
data = data[data.city_or_county != 'Richton Park']
data = data[data.city_or_county != 'Humble']
data = data[data.city_or_county != 'Lynwood']
data = data[data.city_or_county != 'Kent']
data = data[data.city_or_county != 'Maywood']
data = data[data.city_or_county != 'Granada Hills']
data = data[data.city_or_county != 'Lawton']
data = data[data.city_or_county != 'Mesopotamia']
data = data[data.city_or_county != 'San Fernando']
data = data[data.city_or_county != 'Davidson (County)']
data = data[data.city_or_county != 'Montgomery']
data = data[data.city_or_county != 'Pacoima (Arleta)']
data = data[data.city_or_county != 'Halethorpe (Lansdowne)']
data = data[data.city_or_county != 'East Peoria']
data = data[data.city_or_county != 'Mayfield']
data = data[data.city_or_county != 'Cleveland (Parma)']
data = data[data.city_or_county != 'Hays County']
data = data[data.city_or_county != 'Marion']
data = data[data.city_or_county != 'Saint Augustine (St Augustine)']
data = data[data.city_or_county != 'Longview']
data = data[data.city_or_county != 'Silver City']
data = data[data.city_or_county != 'Buda']
data = data[data.city_or_county != 'Miami-dade (county)']
data = data[data.city_or_county != 'Martin']
data = data[data.city_or_county != 'Pierson']
data = data[data.city_or_county != 'Haines City']
data = data[data.city_or_county != 'Havelock']
data = data[data.city_or_county != 'Knox County']
data = data[data.city_or_county != 'Lincoln Park']
data = data[data.city_or_county != 'Colton']
data = data[data.city_or_county != 'Palmdale']
data = data[data.city_or_county != 'Okmulge']
data = data[data.city_or_county != 'Boswell']
data = data[data.city_or_county != 'Bedford']
data = data[data.city_or_county != 'Post Charlotte']
data = data[data.city_or_county != 'Enfield']
data = data[data.city_or_county != 'Okeechobee']
data = data[data.city_or_county != 'Lodi']
data = data[data.city_or_county != 'Hilliard']
data = data[data.city_or_county != 'Coral Gables']
data = data[data.city_or_county != 'San Juan Capistrano']
data = data[data.city_or_county != 'Oak Creek']
data = data[data.city_or_county != 'Palo Alto']
data = data[data.city_or_county != 'Ilion']
data = data[data.city_or_county != 'Middlesex']
data = data[data.city_or_county != 'Fort Mohave']
data = data[data.city_or_county != 'Pond Creek']
data = data[data.city_or_county != 'Chapel Hill']
data = data[data.city_or_county != 'Brighton']
data = data[data.city_or_county != 'Cookville']
data = data[data.city_or_county != 'Nanticoke']
data = data[data.city_or_county != 'Bladensburg']
data = data[data.city_or_county != 'Bryan']
data = data[data.city_or_county != 'Roseville']
data = data[data.city_or_county != 'Clay County']
data = data[data.city_or_county != 'Bellingham']
data = data[data.city_or_county != 'Covington (Ludlow)']
data = data[data.city_or_county != 'Morrisville']
data = data[data.city_or_county != 'Benton Harbor']
data = data[data.city_or_county != 'Sheraden']
data = data[data.city_or_county != 'Bethlehem']
data = data[data.city_or_county != 'North Highlands']
data = data[data.city_or_county != 'Brownsville']
data = data[data.city_or_county != 'Holyoke']
data = data[data.city_or_county != 'Orange Park']
data = data[data.city_or_county != 'Dolton']
data = data[data.city_or_county != 'Royal City']
data = data[data.city_or_county != 'Miami (Goulds)']
data = data[data.city_or_county != 'Cincinnati (Fairmount)']
data = data[data.city_or_county != 'Oshkosh']
data = data[data.city_or_county != 'Huron']
data = data[data.city_or_county != 'Taylorsville']
data = data[data.city_or_county != 'Milton']
data = data[data.city_or_county != 'Sheboygan']
data = data[data.city_or_county != 'Shelby']
data = data[data.city_or_county != 'Muskogee']
data = data[data.city_or_county != 'Fruitridge']
data = data[data.city_or_county != 'Lynchburg']
data = data[data.city_or_county != 'Kokomo']
data = data[data.city_or_county != 'Bernalillo (county)']
data = data[data.city_or_county != 'Morehead']
data = data[data.city_or_county != 'Mount Airy']
data = data[data.city_or_county != 'Blue Island']
data = data[data.city_or_county != 'Barberton']
data = data[data.city_or_county != 'Sugar Land']
data = data[data.city_or_county != 'Prineville']
data = data[data.city_or_county != 'Braintree']
data = data[data.city_or_county != 'Lynn']
data = data[data.city_or_county != 'Bangor']
data = data[data.city_or_county != 'Kernersville']
data = data[data.city_or_county != 'Mesquite']
data = data[data.city_or_county != 'Englewood']
data = data[data.city_or_county != 'Carleton']
data = data[data.city_or_county != 'Severn']
data = data[data.city_or_county != 'Maybrook']
data = data[data.city_or_county != 'Germantown']
data = data[data.city_or_county != 'Schenectady (Glenville)']
data = data[data.city_or_county != 'Traverse City']
data = data[data.city_or_county != 'Las Cruces']
data = data[data.city_or_county != 'Lewisburg']
data = data[data.city_or_county != 'New Albany']
data = data[data.city_or_county != 'Highland']
data = data[data.city_or_county != 'Palm Bay']
data = data[data.city_or_county != 'Cutler']
data = data[data.city_or_county != 'Southfield']
data = data[data.city_or_county != 'Saline']
data = data[data.city_or_county != 'Burbank']
data = data[data.city_or_county != 'Paris']
data = data[data.city_or_county != 'Tooele']
data = data[data.city_or_county != 'Haywood (county)']
data = data[data.city_or_county != 'Clewiston']
data = data[data.city_or_county != 'Rosharon']
data= data.sample(frac=1)
data = data[data.city_or_county != 'Clovis']
data = data[data.city_or_county != 'Booneville']
data = data[data.city_or_county != 'League City']
data = data[data.city_or_county != 'Cordell']
data = data[data.city_or_county != 'Sunbury']
data = data[data.city_or_county != 'Spokane']
data = data[data.city_or_county != 'Bay Point']
data = data[data.city_or_county != 'Laurinburg']
data = data[data.city_or_county != 'Carlisle (county)']
data = data[data.city_or_county != 'Muncie']
data = data[data.city_or_county != 'Scotland (county)']
data = data[data.city_or_county != 'Pickett']
data = data[data.city_or_county != 'South Bay']
data = data[data.city_or_county != 'Mascotte']
data = data[data.city_or_county != 'Fort Lauderdale (Dania Beach)']
data = data[data.city_or_county != 'Port Orange']
data = data[data.city_or_county != 'Okmulgee']
data = data[data.city_or_county != 'Borger']
data = data[data.city_or_county != 'Chagrin Falls']
data = data[data.city_or_county != 'Jamaica']
data = data[data.city_or_county != 'Gardnerville']
data = data[data.city_or_county != 'Spring Lake']
data = data[data.city_or_county != 'Lowell']
data = data[data.city_or_county != 'Mansfield']
data = data[data.city_or_county != 'Sharon']
data = data[data.city_or_county != 'Denton']
data = data[data.city_or_county != 'Avon Park']
data = data[data.city_or_county != 'Irving']
data = data[data.city_or_county != 'Tonopah']
data = data[data.city_or_county != 'Ripley']
data = data[data.city_or_county != 'Berkeley']
data = data[data.city_or_county != 'Palos Park']
data = data[data.city_or_county != 'Hobart']
data = data[data.city_or_county != 'Greenwood']
data = data[data.city_or_county != 'Fort Bend County']
data = data[data.city_or_county != 'Saint Pauls']
data = data[data.city_or_county != 'Roma (Fronton)']
data = data[data.city_or_county != 'Parker']
data = data[data.city_or_county != 'Dover']
data = data[data.city_or_county != 'Pottstown']
data = data[data.city_or_county != 'Rosenberg']
data = data[data.city_or_county != 'Oregon House']
data = data[data.city_or_county != 'Sugar Grove']
data = data[data.city_or_county != 'Duncannon']
data = data[data.city_or_county != 'Pleasanton']
data = data[data.city_or_county != 'Rochester (Irondequoit)']
data = data[data.city_or_county != 'Indialantic']
data = data[data.city_or_county != 'Rutherford (county)']
data = data[data.city_or_county != 'Groveport']
data = data[data.city_or_county != 'Orange Grove']
data = data[data.city_or_county != 'Tampa (Temple Terrace)']
data = data[data.city_or_county != 'Randallstown']
data = data[data.city_or_county != 'Huntington']
data = data[data.city_or_county != 'Revere']
data = data[data.city_or_county != 'Fruita']
data = data[data.city_or_county != 'Martinez']
data = data[data.city_or_county != 'Santa Clarita']
data = data[data.city_or_county != 'Littlestown']
data = data[data.city_or_county != 'Mechanicsburg']
data = data[data.city_or_county != 'Levy (county)']
data = data[data.city_or_county != 'Battle Creek']
data = data[data.city_or_county != 'Bay City']
data = data[data.city_or_county != 'Bel Air']
data = data[data.city_or_county != 'Bellaire']
data = data[data.city_or_county != 'Mechanicsburg']
data = data[data.city_or_county != 'Bell Gardens (Cudahy)']
data = data[data.city_or_county != 'Bexar County']
data = data[data.city_or_county != 'Black Mountain']
data = data[data.city_or_county != 'Bradyville']
data = data[data.city_or_county != 'Bremerton (East Bremerton)']
data = data[data.city_or_county != 'Brentwood']
data = data[data.city_or_county != 'Bridgeview']
data = data[data.city_or_county != 'Brookpark (Brook Park)']
data = data[data.city_or_county != 'Brooksville']
data = data[data.city_or_county != 'Bulverde']
data = data[data.city_or_county != 'Bunola']
data = data[data.city_or_county != 'Burleson']
data = data[data.city_or_county != 'Burns']
data = data[data.city_or_county != 'Buzzards Bay (Bourne)']
data = data[data.city_or_county != 'Caldwell (County)']
data = data[data.city_or_county != 'Cameron']
data = data[data.city_or_county != 'Capulin']
data = data[data.city_or_county != 'Carbondale']
data = data[data.city_or_county != 'Carmel']
data = data[data.city_or_county != 'Cathedral City']
data = data[data.city_or_county != 'Chambersburg']
data = data[data.city_or_county != 'Chardon (Concord Township)']
data = data[data.city_or_county != 'Charter Twp of Clinton']
data = data[data.city_or_county != 'Cheatham County']
data = data[data.city_or_county != 'Cherryville']
data = data[data.city_or_county != 'Christmas']
data = data[data.city_or_county != 'Chula Vista']
data = data[data.city_or_county != 'Cincinnati (Lockland)']
data = data[data.city_or_county != 'Cisco']
data = data[data.city_or_county != 'Claremore']
data = data[data.city_or_county != 'Clermont']
data = data[data.city_or_county != 'Cleveland (County)']
data = data[data.city_or_county != 'Clinton']
data = data[data.city_or_county != 'Clinton Township']
data = data[data.city_or_county != 'Clinton TOwnship (Charter (Twp of Clinton))']
data = data[data.city_or_county != 'Coffee (County)']
data = data[data.city_or_county != 'Colbert']
data = data[data.city_or_county != 'Colorado Springs (Colorado Springs)']
data = data[data.city_or_county != 'Columbia']
data = data[data.city_or_county != 'Commerce']
data = data[data.city_or_county != 'Concord']
data = data[data.city_or_county != 'Conover']
data = data[data.city_or_county != 'Cookeville']
data = data[data.city_or_county != 'Coral Springs']
data = data[data.city_or_county != 'Cromwell']
data = data[data.city_or_county != 'Crum Lynne']
data = data[data.city_or_county != 'Dania Beach']
data = data[data.city_or_county != 'Darby (Colwyn)']
data = data[data.city_or_county != 'Clinton']
data = data[data.city_or_county != 'Davidson (county)']
data = data[data.city_or_county != 'Davidson County']
data = data[data.city_or_county != 'Deer Park']
data = data[data.city_or_county != 'Deland']
data = data[data.city_or_county != 'Delray Beach']
data = data[data.city_or_county != 'Denison']
data = data[data.city_or_county != 'Dewitt']
data = data[data.city_or_county != 'Duarte']
data = data[data.city_or_county != 'Dudley']
data = data[data.city_or_county != 'Dumas']
data = data[data.city_or_county != 'Durango']
data = data[data.city_or_county != 'East Bernstadt']
data = data[data.city_or_county != 'Elizabethtown']
data = data[data.city_or_county != 'Elk Grove']
data = data[data.city_or_county != 'Ellicott City']
data = data[data.city_or_county != 'Escondido']
data = data[data.city_or_county != 'Essexville']
data = data[data.city_or_county != 'Eufala']
data = data[data.city_or_county != 'Eugene']
data = data[data.city_or_county != 'Evansville (Darmstadt)']
data = data[data.city_or_county != 'Fairfiew']
data = data[data.city_or_county != 'Fairview Heights']
data = data[data.city_or_county != 'Falfurrias']
data = data[data.city_or_county != 'Ferris']
data = data[data.city_or_county != 'Florence']
data = data[data.city_or_county != 'Flour Bluff']
data = data[data.city_or_county != 'Fort Bend (county)']
data = data[data.city_or_county != 'Fort Lauderdale (Lauderhill)']
data = data[data.city_or_county != 'Fort Walton Beach (Okaloosa Island)']
data = data[data.city_or_county != 'Fort Washington']
data = data[data.city_or_county != 'Fostoria']
data = data[data.city_or_county != 'Fountain']
data = data[data.city_or_county != 'Frankling (county)']
data = data[data.city_or_county != 'Franklinton']
data = data[data.city_or_county != 'Freeland']
data = data[data.city_or_county != 'Gatesville']
data = data[data.city_or_county != 'Gilroy']
data = data[data.city_or_county != 'Glenolden']
data = data[data.city_or_county != 'Grand Terrace']
data = data[data.city_or_county != 'Greenup']
data = data[data.city_or_county != 'Grulla (La Grulla)']
data = data[data.city_or_county != 'Gwynn Oak']
data = data[data.city_or_county != 'Hallandale (Hallandale Beach)']
data = data[data.city_or_county != 'Hastings']
data = data[data.city_or_county != 'Hawley']
data = data[data.city_or_county != 'Hempstead']
data = data[data.city_or_county != 'Hocking (county)']
data = data[data.city_or_county != 'Hocking County']
data = data[data.city_or_county != 'Hollywood (West Park)']
data = data[data.city_or_county != 'Hoopa']
data = data[data.city_or_county != 'Huntley']
data = data[data.city_or_county != 'Huntsville']
data = data[data.city_or_county != 'Hurst']
data = data[data.city_or_county != 'Hyattsville']
data = data[data.city_or_county != 'Indiana']
data = data[data.city_or_county != 'Clinton']
data = data[data.city_or_county != 'Jamestown']
data = data[data.city_or_county != 'Jerseyville']
data = data[data.city_or_county != 'Jessup']
data = data[data.city_or_county != 'Jonesboro']
data = data[data.city_or_county != 'Kemp']
data = data[data.city_or_county != 'Kenton']
data = data[data.city_or_county != 'Kenwood']
data = data[data.city_or_county != 'Kings Mountain']
data = data[data.city_or_county != 'Knox']
data = data[data.city_or_county != 'Kosciusko (county)']
data = data[data.city_or_county != 'Kountze']
data = data[data.city_or_county != 'Kutztown']
data = data[data.city_or_county != 'La Center']
data = data[data.city_or_county != 'La Plata']
data = data[data.city_or_county != 'La Puente']
data = data[data.city_or_county != 'Lacey']
data = data[data.city_or_county != 'Lafayette']
data = data[data.city_or_county != 'Lake City']
data = data[data.city_or_county != 'Lake Worth']
data = data[data.city_or_county != 'Lakewood']
data = data[data.city_or_county != 'Lamont']
data = data[data.city_or_county != 'Layton']
data = data[data.city_or_county != 'Lemon Grove']
data = data[data.city_or_county != 'Lewisville']
data = data[data.city_or_county != 'Lillington']
data = data[data.city_or_county != 'London']
data = data[data.city_or_county != 'Lovejoy (Brooklyn)']
data = data[data.city_or_county != 'Mabank']
data = data[data.city_or_county != 'Mabton']
data = data[data.city_or_county != 'Madera']
data = data[data.city_or_county != 'Manheim']
data = data[data.city_or_county != 'Manvel']
data = data[data.city_or_county != 'Martinez (Pacheco)']
data = data[data.city_or_county != 'Massillon']
data = data[data.city_or_county != 'Mathis']
data = data[data.city_or_county != 'Medford']
data = data[data.city_or_county != 'Milan']
data = data[data.city_or_county != 'Mishawaka']
data = data[data.city_or_county != 'Moline']
data = data[data.city_or_county != 'Monroe']
data = data[data.city_or_county != 'Mooresboro']
data = data[data.city_or_county != 'Morenci']
data = data[data.city_or_county != 'Mounds']
data = data[data.city_or_county != 'Mountville']
data = data[data.city_or_county != 'Nazareth']
data = data[data.city_or_county != 'New Caney']
data = data[data.city_or_county != 'New Freedom']
data = data[data.city_or_county != 'New Paltz']
data = data[data.city_or_county != 'Newbern']
data = data[data.city_or_county != 'Newman']
data = data[data.city_or_county != 'Newport']
data = data[data.city_or_county != 'Norlina']
data = data[data.city_or_county != 'North Manchester']
data = data[data.city_or_county != 'North Richland Hills']
data = data[data.city_or_county != 'North Tonawanda']
data = data[data.city_or_county != 'Northwood']
data = data[data.city_or_county != 'Ogden (South Ogden)']
data = data[data.city_or_county != 'Onalaska']
data = data[data.city_or_county != 'Onslow (county)']
data = data[data.city_or_county != 'Opa Locka']
data = data[data.city_or_county != 'Orange']
data = data[data.city_or_county != 'Orangeville']
data = data[data.city_or_county != 'Owings Mills']
data = data[data.city_or_county != 'Pahokee']
data = data[data.city_or_county != 'Palatka']
data = data[data.city_or_county != 'Pana']
data = data[data.city_or_county != 'Panama City']
data = data[data.city_or_county != 'Paradise']
data = data[data.city_or_county != 'Pinetop']
data = data[data.city_or_county != 'Pittsburg (Bay Point)']
data = data[data.city_or_county != 'Pittsburgh (Mount Oliver)']
data = data[data.city_or_county != 'Plantation']
data = data[data.city_or_county != 'Pleasant Hills']
data = data[data.city_or_county != 'Pompano Beach (North Lauderdale)']
data = data[data.city_or_county != 'Port Arthur']
data = data[data.city_or_county != 'Port Charlotte']
data = data[data.city_or_county != 'Port Ludlow']
data = data[data.city_or_county != 'Powell']
data = data[data.city_or_county != 'Princeton']
data = data[data.city_or_county != 'Ramona']
data = data[data.city_or_county != 'Rancho Cordova']
data = data[data.city_or_county != 'Red Valley']
data = data[data.city_or_county != 'Redford Charter Township']
data = data[data.city_or_county != 'Represa']
data = data[data.city_or_county != 'Reynoldsburg']
data = data[data.city_or_county != 'Richfield']
data = data[data.city_or_county != 'Riverdale']
data = data[data.city_or_county != 'Roanoke Rapids']
data = data[data.city_or_county != 'Robeson (county)']
data = data[data.city_or_county != 'Rockledge']
data = data[data.city_or_county != 'Rockport']
data = data[data.city_or_county != 'Romeovile']
data = data[data.city_or_county != 'Roosevelt']
data = data[data.city_or_county != 'Rosedale']
data = data[data.city_or_county != 'Royersford (Limerick)']
data = data[data.city_or_county != 'Royse City']
data = data[data.city_or_county != 'Ruidoso']
data = data[data.city_or_county != 'Rush Springs']
data = data[data.city_or_county != 'Ruskin']
data = data[data.city_or_county != 'Russellville']
data = data[data.city_or_county != 'Clinton']
data = data[data.city_or_county != 'Russiaville']
data = data[data.city_or_county != 'Rutherfordton']
data = data[data.city_or_county != 'Saginaw Township']
data = data[data.city_or_county != 'Saint Louis']
data = data[data.city_or_county != 'San Pablo']
data = data[data.city_or_county != 'Santa Maria']
data = data[data.city_or_county != 'Santaquin']
data = data[data.city_or_county != 'Schiller Park']
data = data[data.city_or_county != 'Scottsdale']
data = data[data.city_or_county != 'Scranton']
data = data[data.city_or_county != 'Seagoville']
data = data[data.city_or_county != 'Sebastopol']
data = data[data.city_or_county != 'Seminole']
data = data[data.city_or_county != 'Shannon']
data = data[data.city_or_county != 'Shermans Dale']
data = data[data.city_or_county != 'Shingle Springs']
data = data[data.city_or_county != 'Soddy Daisy']
data = data[data.city_or_county != 'Somerset']
data = data[data.city_or_county != 'Sonora']
data = data[data.city_or_county != 'Sparks']
data = data[data.city_or_county != 'Spring (Shenandoah)']
data = data[data.city_or_county != 'Springboro']
data = data[data.city_or_county != 'Springfield (Gardens)']
data = data[data.city_or_county != 'St Petersburg']
data = data[data.city_or_county != 'St. Joseph (county)']
data = data[data.city_or_county != 'Stillwater']
data = data[data.city_or_county != 'Stone']
data = data[data.city_or_county != 'Suitland']
data = data[data.city_or_county != 'Sylmar (Lake View Terrace)']
data = data[data.city_or_county != 'Taloga']
data = data[data.city_or_county != 'Taylor']
data = data[data.city_or_county != 'Tehama County']
data = data[data.city_or_county != 'Temple Terrace']
data = data[data.city_or_county != 'Theresa']
data = data[data.city_or_county != 'Torrance']
data = data[data.city_or_county != 'Trinity']

# %%
def get_user_mapping(txt):
    if txt == "NA":
        return {}
    mapping = {}
    for d in txt.split("||"):
        try:
            key = d.split("::")[0]
            val = d.split("::")[1] 
            if key not in mapping:
                mapping[key] = val
        except:
            pass
    return mapping

# %%
data['participant_type'] = data['participant_type'].apply(lambda x : get_user_mapping (x))

# %%
data_types = data['participant_type'].apply(pd.Series)

# %%
data_types.head()
# Out:
#              0       1   10   11   12   13   14   15   16                2  \
# 213735  Victim  Victim  NaN  NaN  NaN  NaN  NaN  NaN  NaN           Victim
# 219418  Victim  Victim  NaN  NaN  NaN  NaN  NaN  NaN  NaN           Victim
# 209609  Victim  Victim  NaN  NaN  NaN  NaN  NaN  NaN  NaN           Victim
# 144844  Victim  Victim  NaN  NaN  NaN  NaN  NaN  NaN  NaN  Subject-Suspect
# 53933   Victim  Victim  NaN  NaN  NaN  NaN  NaN  NaN  NaN  Subject-Suspect
#
#                       3                4    5    6    7    8    9
# 213735           Victim              NaN  NaN  NaN  NaN  NaN  NaN
# 219418  Subject-Suspect  Subject-Suspect  NaN  NaN  NaN  NaN  NaN
# 209609              NaN              NaN  NaN  NaN  NaN  NaN  NaN
# 144844              NaN              NaN  NaN  NaN  NaN  NaN  NaN
# 53933   Subject-Suspect              NaN  NaN  NaN  NaN  NaN  NaN

# %%
data['participant_age'] = data['participant_age'].fillna("NA")
data['participant_age_map'] = data['participant_age'].apply(lambda x : get_user_mapping (x))

# %%
data_ages = data['participant_age_map'].apply(pd.Series)

# %%
data_ages.head()
# Out:
#          0    1   12   15   16    2    3    4    5    6    7    8    9
# 213735   4   31  NaN  NaN  NaN   30   35  NaN  NaN  NaN  NaN  NaN  NaN
# 219418  32   21  NaN  NaN  NaN   24   22   24  NaN  NaN  NaN  NaN  NaN
# 209609  29  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 144844  24   26  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 53933   15   18  NaN  NaN  NaN   18   20  NaN  NaN  NaN  NaN  NaN  NaN

# %%
data = data.join(data_ages, rsuffix='_ages')
data = data.join(data_types, rsuffix='_types')

# %%
print(data)
# Out:
#               date          state       city_or_county  n_killed  n_injured  \
# 213735  2017-10-15          Texas              Houston         2          2
# 219418  2017-11-19        Indiana         Indianapolis         2          1
# 209609  2017-09-21       Kentucky           Louisville         1          2
# 144844  2016-09-05       Illinois  Chicago (Englewood)         1          1
# 53933   2015-01-15          Texas              Houston         1          1
# 224936  2017-12-25        Arizona              Phoenix         3          1
# 73465   2015-06-04        Arizona              Phoenix         1          1
# 192828  2017-06-14      Wisconsin            Milwaukee         1          1
# 177079  2017-03-19       Kentucky           Louisville         1          5
# 150840  2016-10-12   Pennsylvania         Philadelphia         1          1
# 90654   2015-09-19        Indiana         Indianapolis         1          3
# ...

# %%
data.head()
# Out:
#               date     state       city_or_county  n_killed  n_injured  \
# 213735  2017-10-15     Texas              Houston         2          2
# 219418  2017-11-19   Indiana         Indianapolis         2          1
# 209609  2017-09-21  Kentucky           Louisville         1          2
# 144844  2016-09-05  Illinois  Chicago (Englewood)         1          1
# 53933   2015-01-15     Texas              Houston         1          1
#
#                           participant_age  \
# 213735          0::4||1::31||2::30||3::35
# 219418  0::32||1::21||2::24||3::22||4::24
# 209609                              0::29
# 144844                       0::24||1::26
# 53933          0::15||1::18||2::18||3::20
#
#                                     participant_age_group  \
# 213735  0::Child 0-11||1::Adult 18+||2::Adult 18+||3::...
# 219418  0::Adult 18+||1::Adult 18+||2::Adult 18+||3::A...
# 209609           0::Adult 18+||1::Adult 18+||2::Adult 18+
# ...

# %%
data['types'] = data_types['1']

# %%
df = data[['1', 'n_killed', 'types']]
df = df[df.types != 'Victim']
df = df.dropna()
df['age'] = df['1']
df = df.groupby(df.age).sum()
df = df.reset_index()

# %%
df
# Out:
#    age  n_killed
# 0   15         3
# 1   16         4
# 2   17         5
# 3   18         8
# 4   19        10
# 5   20        13
# 6   21         7
# 7   22        12
# 8   23         6
# 9   24         4
# 10  25         9
# 11  26        10
# 12  27         5
# 13  28        10
# 14  29        10
# 15  30         5
# 16  31         6
# 17  32         9
# 18  33         8
# 19  34         2
# 20  35         6
# 21  36         3
# 22  37         6
# 23  38         3
# 24  39         1
# 25  40         3
# 26  41         5
# 27  42         1
# 28  43         3
# 29  44         4
# 30  45         3
# 31  46         5
# 32  47         1
# 33  48         1
# 34  49         2
# 35  50         1
# 36  51         2
# 37  52         1
# 38  53         1
# 39  54         2
# 40  55         2
# 41  56         1
# 42  57         1
# 43  58         2
# 44  59         1
# 45  62         2
# 46  70         1
# 47  74         1
# 48  80         1
# 49  96         1

# %%
#Installing modules

# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from six.moves import range
import seaborn as sns
import sklearn
import statsmodels.api as sm
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
plt.figure(figsize=(10,20))
plt.barh(data['city_or_county'], data['n_killed'])

plt.show()

# %%
df =  df.sort_values(by=['age'])

# %%
plt.figure(figsize=(20,10))

plt.scatter(df['age'], df['n_killed'])

plt.show()

# %%
x = df['age'].values.reshape(-1, 1)
y = df['n_killed'].values.reshape(-1, 1)

# %%
import scipy

# %%
from scipy.optimize import curve_fit

# %%
def func(x, a, b, c):
    return a * np.exp(-b * x) + c

# %%
xdata = df['age'].values.reshape(-1, 1).astype(int)
ydata = df['n_killed'].values.reshape(-1, 1)

# %%
popt, pcov = curve_fit(func, xdata.ravel(), ydata.ravel())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp

# %%
popt, pcov
# Out:
# (array([16.31114114,  0.02027854, -3.27055206]),
#  array([[ 1.06581304e+01, -3.39298581e-02, -1.39914563e+01],
#         [-3.39298581e-02,  2.17160486e-04,  7.37267686e-02],
#         [-1.39914563e+01,  7.37267686e-02,  2.62867713e+01]]))

# %%
plt.plot(xdata, func(xdata, *popt))
